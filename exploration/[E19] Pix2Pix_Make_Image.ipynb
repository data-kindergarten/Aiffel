# %% [markdown]
# # 프로젝트명 : Segmentation map으로 도로 이미지 만들기

# %% [markdown]
# ### 루브릭

# %% [markdown]
# |No.|평가문항|상세기준|
# |:---|:---|:---|
# |1|pix2pix 모델 학습을 위해 필요한 데이터셋을 적절히 구축하였다.|데이터 분석 과정 및 한 가지 이상의 augmentation을 포함한 데이터셋 구축 과정이 체계적으로 제시되었다.|
# |2|pix2pix 모델을 구현하여 성공적으로 학습 과정을 진행하였다.|U-Net generator, discriminator 모델 구현이 완료되어 train_step이 안정적으로 진행됨을 확인하였다.|
# |3|학습 과정 및 테스트에 대한 시각화 결과를 제출하였다.|10 epoch 이상의 학습을 진행한 후 최종 테스트 결과에서 진행한 epoch 수에 걸맞은 정도의 품질을 확인하였다.|

# %% [markdown]
# ## 1. 데이터 준비

# %%
# 데이터 개수 확인하기
import os

data_path = os.getenv('HOME') + '/aiffel/exploration/E19/data/cityscapes/train/'
print("데이터 개수:", len(os.listdir(data_path)))
# Out:
# 데이터 개수: 1000

# %%
# 데이터 샘플 확인하기
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
# 샘플 이미지의 크기 확인
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
# 이미지 분할하기 (256, 256, 3)
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    orig_image = img[:, :w, :] 
    orig_image = tf.cast(orig_image, tf.float32)
    input_image = img[:, w:, :] 
    input_image = tf.cast(input_image, tf.float32)
    return normalize(input_image), normalize(orig_image)

f = data_path + os.listdir(data_path)[1]
input_image, orig_image = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(input_image))
plt.subplot(1,2,2); plt.imshow(denormalize(orig_image))

# %% [markdown]
# ### Data augmentation 적용

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(input_image, orig_image):
    stacked = tf.concat([input_image, orig_image], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_input_image, augmented_orig_image = apply_augmentation(input_image, orig_image)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_input_image)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_orig_image)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    input_image, orig_image = load_img(img_path)
    input_image, orig_image = apply_augmentation(input_image, orig_image)
    return input_image, orig_image

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
input_image, orig_image = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(input_image[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(orig_image[0].astype(np.uint8))

# %%
from tensorflow import data

def get_train(img_path):
    input_image, orig_image = load_img(img_path)
    input_image, orig_image = apply_augmentation(input_image, orig_image)
    return input_image, orig_image

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
input_image, orig_image = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(input_image[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(orig_image[0].astype(np.uint8))

# %% [markdown]
# ## 2. Generator 구성(U-Net 이용)

# %% [markdown]
# ![img1](https://d3s0tskafalll9.cloudfront.net/media/images/p2p_generator_unet.max-800x600.png)

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block (EncodeBlock)      (None, 128, 128, 64) 3072        input_1[0][0]
# __________________________________________________________________________________________________
# encode_block_1 (EncodeBlock)    (None, 64, 64, 128)  131584      encode_block[0][0]
# __________________________________________________________________________________________________
# encode_block_2 (EncodeBlock)    (None, 32, 32, 256)  525312      encode_block_1[0][0]
# __________________________________________________________________________________________________
# encode_block_3 (EncodeBlock)    (None, 16, 16, 512)  2099200     encode_block_2[0][0]
# __________________________________________________________________________________________________
# encode_block_4 (EncodeBlock)    (None, 8, 8, 512)    4196352     encode_block_3[0][0]
# __________________________________________________________________________________________________
# encode_block_5 (EncodeBlock)    (None, 4, 4, 512)    4196352     encode_block_4[0][0]
# __________________________________________________________________________________________________
# encode_block_6 (EncodeBlock)    (None, 2, 2, 512)    4196352     encode_block_5[0][0]
# __________________________________________________________________________________________________
# encode_block_7 (EncodeBlock)    (None, 1, 1, 512)    4196352     encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 2, 2, 512)    4196352     encode_block_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block[0][0]
#                                                                  encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_1[0][0]
#                                                                  encode_block_5[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_2[0][0]
#                                                                  encode_block_4[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_3[0][0]
#                                                                  encode_block_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_4[0][0]
#                                                                  encode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_5 (DecodeBlock)    (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_5[0][0]
#                                                                  encode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_6 (DecodeBlock)    (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_6[0][0]
#                                                                  encode_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3. Discriminator 구성하기

# %% [markdown]
# ![img2](https://d3s0tskafalll9.cloudfront.net/media/images/patchgan.max-800x600.png)

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %% [markdown]
# ## 4. 학습 및 테스트

# %% [markdown]
# ### 손실함수

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %% [markdown]
# ### 최적화(Optimizer)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %% [markdown]
# ### 가중치 업데이트

# %%
@tf.function
def train_step(input_image, orig_image):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_image = generator(input_image, training=True)
        # Discriminator 예측
        fake_disc = discriminator(input_image, fake_image, training=True)
        real_disc = discriminator(input_image, orig_image, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_image, orig_image, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %% [markdown]
# ### 학습 진행

# %%
EPOCHS = 200 

generator = UNetGenerator()
discriminator = Discriminator()
history = {'gen_loss':[], 'l1_loss':[], 'disc_loss':[]}

for epoch in range(1, EPOCHS+1):
    for i, (input_image, orig_image) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(input_image, orig_image)
        history['gen_loss'].append(g_loss)
        history['l1_loss'].append(l1_loss)
        history['disc_loss'].append(d_loss)
        
        # 200회 반복마다 손실을 출력합니다.
        if (i+1) % 200 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[200]
# Generator_loss:1.8996
# L1_loss:0.1957
# Discriminator_loss:0.4860
#
# EPOCH[2] - STEP[200]
# Generator_loss:3.0403
# L1_loss:0.1514
# Discriminator_loss:1.6059
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.4586
# L1_loss:0.1900
# Discriminator_loss:0.4264
#
# EPOCH[4] - STEP[200]
# Generator_loss:2.2167
# L1_loss:0.1894
# Discriminator_loss:0.4915
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.3858
# L1_loss:0.1937
# Discriminator_loss:0.5028
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.5185
# L1_loss:0.1974
# Discriminator_loss:0.5875
#
# EPOCH[7] - STEP[200]
# Generator_loss:2.2019
# L1_loss:0.1983
# Discriminator_loss:0.6680
#
# EPOCH[8] - STEP[200]
# Generator_loss:0.8286
# L1_loss:0.1784
# Discriminator_loss:1.1658
#
# EPOCH[9] - STEP[200]
# Generator_loss:2.5810
# L1_loss:0.1710
# Discriminator_loss:0.9098
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.5260
# L1_loss:0.2081
# Discriminator_loss:0.3515
#
# EPOCH[11] - STEP[200]
# Generator_loss:0.2981
# L1_loss:0.2154
# Discriminator_loss:1.6593
#
# EPOCH[12] - STEP[200]
# Generator_loss:1.3568
# L1_loss:0.1995
# Discriminator_loss:0.6735
#
# EPOCH[13] - STEP[200]
# Generator_loss:1.7787
# L1_loss:0.1806
# Discriminator_loss:0.3938
#
# EPOCH[14] - STEP[200]
# Generator_loss:1.5218
# L1_loss:0.1664
# Discriminator_loss:0.8286
#
# EPOCH[15] - STEP[200]
# Generator_loss:1.7812
# L1_loss:0.1715
# Discriminator_loss:0.8861
#
# EPOCH[16] - STEP[200]
# Generator_loss:1.3953
# L1_loss:0.1911
# Discriminator_loss:0.6513
#
# EPOCH[17] - STEP[200]
# Generator_loss:0.6867
# L1_loss:0.1514
# Discriminator_loss:1.5206
#
# EPOCH[18] - STEP[200]
# Generator_loss:2.6460
# L1_loss:0.1821
# Discriminator_loss:0.3212
#
# EPOCH[19] - STEP[200]
# Generator_loss:2.6737
# L1_loss:0.1421
# Discriminator_loss:1.8964
#
# EPOCH[21] - STEP[200]
# Generator_loss:0.9474
# L1_loss:0.1706
# Discriminator_loss:1.5071
#
# EPOCH[22] - STEP[200]
# Generator_loss:1.1263
# L1_loss:0.1653
# Discriminator_loss:0.9390
#
# EPOCH[23] - STEP[200]
# Generator_loss:0.8104
# L1_loss:0.1973
# Discriminator_loss:0.9418
#
# EPOCH[24] - STEP[200]
# Generator_loss:1.6419
# L1_loss:0.1696
# Discriminator_loss:2.1492
#
# EPOCH[25] - STEP[200]
# Generator_loss:0.9138
# L1_loss:0.2053
# Discriminator_loss:0.6185
#
# EPOCH[26] - STEP[200]
# Generator_loss:1.2453
# L1_loss:0.2137
# Discriminator_loss:0.4310
#
# EPOCH[27] - STEP[200]
# Generator_loss:1.5670
# L1_loss:0.1972
# Discriminator_loss:0.6926
#
# EPOCH[28] - STEP[200]
# Generator_loss:1.6322
# L1_loss:0.2312
# Discriminator_loss:0.3148
#
# EPOCH[29] - STEP[200]
# Generator_loss:1.3761
# L1_loss:0.1793
# Discriminator_loss:1.4233
#
# EPOCH[30] - STEP[200]
# Generator_loss:2.6282
# L1_loss:0.1869
# Discriminator_loss:0.2692
#
# EPOCH[31] - STEP[200]
# Generator_loss:0.5669
# L1_loss:0.1829
# Discriminator_loss:1.0639
#
# EPOCH[32] - STEP[200]
# Generator_loss:0.7576
# L1_loss:0.1552
# Discriminator_loss:0.8661
#
# EPOCH[33] - STEP[200]
# Generator_loss:1.5516
# L1_loss:0.1542
# Discriminator_loss:1.2156
#
# EPOCH[34] - STEP[200]
# Generator_loss:2.1938
# L1_loss:0.2168
# Discriminator_loss:0.1423
#
# EPOCH[35] - STEP[200]
# Generator_loss:1.8803
# L1_loss:0.1961
# Discriminator_loss:1.5588
#
# EPOCH[36] - STEP[200]
# Generator_loss:1.5305
# L1_loss:0.1720
# Discriminator_loss:1.2022
#
# EPOCH[37] - STEP[200]
# Generator_loss:1.0898
# L1_loss:0.1673
# Discriminator_loss:0.5819
#
# EPOCH[38] - STEP[200]
# Generator_loss:0.3811
# L1_loss:0.1750
# Discriminator_loss:1.5270
#
# EPOCH[39] - STEP[200]
# Generator_loss:1.0776
# L1_loss:0.1559
# Discriminator_loss:1.0884
#
# EPOCH[40] - STEP[200]
# Generator_loss:2.4916
# L1_loss:0.1677
# Discriminator_loss:1.8022
#
# EPOCH[41] - STEP[200]
# Generator_loss:1.5358
# L1_loss:0.1897
# Discriminator_loss:0.3070
#
# EPOCH[42] - STEP[200]
# Generator_loss:0.6870
# L1_loss:0.1885
# Discriminator_loss:0.9035
#
# EPOCH[43] - STEP[200]
# Generator_loss:1.1585
# L1_loss:0.2103
# Discriminator_loss:0.5314
#
# EPOCH[44] - STEP[200]
# Generator_loss:1.2447
# L1_loss:0.1899
# Discriminator_loss:0.4811
#
# EPOCH[45] - STEP[200]
# Generator_loss:1.9906
# L1_loss:0.1667
# Discriminator_loss:0.4926
#
# EPOCH[46] - STEP[200]
# Generator_loss:2.6731
# L1_loss:0.1698
# Discriminator_loss:1.4096
#
# EPOCH[47] - STEP[200]
# Generator_loss:1.7914
# L1_loss:0.1596
# Discriminator_loss:0.4403
#
# EPOCH[48] - STEP[200]
# Generator_loss:2.7060
# L1_loss:0.1674
# Discriminator_loss:1.1976
#
# EPOCH[49] - STEP[200]
# Generator_loss:1.4385
# L1_loss:0.1443
# Discriminator_loss:0.8455
#
# EPOCH[50] - STEP[200]
# Generator_loss:1.4398
# L1_loss:0.1818
# Discriminator_loss:0.4104
#
# EPOCH[51] - STEP[200]
# Generator_loss:0.8347
# L1_loss:0.1736
# Discriminator_loss:0.7469
#
# EPOCH[52] - STEP[200]
# Generator_loss:2.1314
# L1_loss:0.1834
# Discriminator_loss:0.4169
#
# EPOCH[53] - STEP[200]
# Generator_loss:1.6011
# L1_loss:0.1750
# Discriminator_loss:0.5375
#
# EPOCH[54] - STEP[200]
# Generator_loss:1.0190
# L1_loss:0.1598
# Discriminator_loss:1.1863
#
# EPOCH[55] - STEP[200]
# Generator_loss:1.5949
# L1_loss:0.1518
# Discriminator_loss:1.1984
#
# EPOCH[56] - STEP[200]
# Generator_loss:0.9877
# L1_loss:0.1541
# Discriminator_loss:0.9370
#
# EPOCH[57] - STEP[200]
# Generator_loss:2.2387
# L1_loss:0.1566
# Discriminator_loss:0.8586
#
# EPOCH[58] - STEP[200]
# Generator_loss:1.1985
# L1_loss:0.1787
# Discriminator_loss:0.6013
#
# EPOCH[59] - STEP[200]
# Generator_loss:2.7330
# L1_loss:0.1810
# Discriminator_loss:0.4119
#
# EPOCH[60] - STEP[200]
# Generator_loss:1.5562
# L1_loss:0.1731
# Discriminator_loss:1.6188
#
# EPOCH[61] - STEP[200]
# Generator_loss:1.1396
# L1_loss:0.1880
# Discriminator_loss:0.5989
#
# EPOCH[62] - STEP[200]
# Generator_loss:0.8831
# L1_loss:0.1585
# Discriminator_loss:0.9613
#
# EPOCH[63] - STEP[200]
# Generator_loss:0.8327
# L1_loss:0.1706
# Discriminator_loss:0.7584
#
# EPOCH[64] - STEP[200]
# Generator_loss:2.1303
# L1_loss:0.1597
# Discriminator_loss:2.0305
#
# EPOCH[65] - STEP[200]
# Generator_loss:1.5942
# L1_loss:0.1779
# Discriminator_loss:0.6464
#
# EPOCH[66] - STEP[200]
# Generator_loss:1.7480
# L1_loss:0.1688
# Discriminator_loss:0.9576
#
# EPOCH[67] - STEP[200]
# Generator_loss:1.1023
# L1_loss:0.1846
# Discriminator_loss:0.6770
#
# EPOCH[68] - STEP[200]
# Generator_loss:1.0833
# L1_loss:0.1552
# Discriminator_loss:1.6101
#
# EPOCH[69] - STEP[200]
# Generator_loss:1.3916
# L1_loss:0.1589
# Discriminator_loss:0.4896
#
# EPOCH[70] - STEP[200]
# Generator_loss:1.0201
# L1_loss:0.1602
# Discriminator_loss:0.7871
#
# EPOCH[71] - STEP[200]
# Generator_loss:1.4485
# L1_loss:0.1697
# Discriminator_loss:0.7669
#
# EPOCH[72] - STEP[200]
# Generator_loss:2.8327
# L1_loss:0.1997
# Discriminator_loss:0.0926
#
# EPOCH[73] - STEP[200]
# Generator_loss:1.7565
# L1_loss:0.1574
# Discriminator_loss:0.4621
#
# EPOCH[74] - STEP[200]
# Generator_loss:0.9034
# L1_loss:0.1572
# Discriminator_loss:1.0956
#
# EPOCH[75] - STEP[200]
# Generator_loss:1.6169
# L1_loss:0.1446
# Discriminator_loss:2.0848
#
# EPOCH[76] - STEP[200]
# Generator_loss:0.5852
# L1_loss:0.1650
# Discriminator_loss:1.3290
#
# EPOCH[77] - STEP[200]
# Generator_loss:1.7836
# L1_loss:0.1633
# Discriminator_loss:0.9244
#
# EPOCH[78] - STEP[200]
# Generator_loss:1.8003
# L1_loss:0.1687
# Discriminator_loss:1.2912
#
# EPOCH[79] - STEP[200]
# Generator_loss:0.3815
# L1_loss:0.2292
# Discriminator_loss:1.2980
#
# EPOCH[80] - STEP[200]
# Generator_loss:1.6170
# L1_loss:0.1638
# Discriminator_loss:1.1832
#
# EPOCH[81] - STEP[200]
# Generator_loss:1.5701
# L1_loss:0.2052
# Discriminator_loss:0.3616
#
# EPOCH[82] - STEP[200]
# Generator_loss:0.9908
# L1_loss:0.1494
# Discriminator_loss:1.2117
#
# EPOCH[83] - STEP[200]
# Generator_loss:2.0004
# L1_loss:0.1648
# Discriminator_loss:1.0284
#
# EPOCH[84] - STEP[200]
# Generator_loss:1.1115
# L1_loss:0.1864
# Discriminator_loss:0.8044
#
# EPOCH[85] - STEP[200]
# Generator_loss:0.5748
# L1_loss:0.1631
# Discriminator_loss:1.1353
#
# EPOCH[86] - STEP[200]
# Generator_loss:1.0885
# L1_loss:0.1389
# Discriminator_loss:1.4793
#
# EPOCH[87] - STEP[200]
# Generator_loss:0.3584
# L1_loss:0.1931
# Discriminator_loss:1.4018
#
# EPOCH[88] - STEP[200]
# Generator_loss:2.4403
# L1_loss:0.2017
# Discriminator_loss:0.1381
#
# EPOCH[89] - STEP[200]
# Generator_loss:1.3166
# L1_loss:0.1322
# Discriminator_loss:1.0856
#
# EPOCH[90] - STEP[200]
# Generator_loss:1.9606
# L1_loss:0.1685
# Discriminator_loss:0.8235
#
# EPOCH[91] - STEP[200]
# Generator_loss:2.1173
# L1_loss:0.1659
# Discriminator_loss:0.4601
#
# EPOCH[92] - STEP[200]
# Generator_loss:1.9028
# L1_loss:0.1676
# Discriminator_loss:1.5925
#
# EPOCH[93] - STEP[200]
# Generator_loss:1.5835
# L1_loss:0.1559
# Discriminator_loss:0.8264
#
# EPOCH[94] - STEP[200]
# Generator_loss:2.2151
# L1_loss:0.1453
# Discriminator_loss:1.6049
#
# EPOCH[95] - STEP[200]
# Generator_loss:1.2052
# L1_loss:0.1703
# Discriminator_loss:0.5714
#
# EPOCH[96] - STEP[200]
# Generator_loss:1.9676
# L1_loss:0.1589
# Discriminator_loss:1.1155
#
# EPOCH[97] - STEP[200]
# Generator_loss:0.8724
# L1_loss:0.1759
# Discriminator_loss:0.7966
#
# EPOCH[98] - STEP[200]
# Generator_loss:0.7118
# L1_loss:0.1968
# Discriminator_loss:0.8659
#
# EPOCH[99] - STEP[200]
# Generator_loss:1.2214
# L1_loss:0.1546
# Discriminator_loss:0.7866
#
# EPOCH[100] - STEP[200]
# Generator_loss:1.7737
# L1_loss:0.1615
# Discriminator_loss:0.5617
#
# EPOCH[101] - STEP[200]
# Generator_loss:1.6984
# L1_loss:0.1879
# Discriminator_loss:0.5826
#
# EPOCH[102] - STEP[200]
# Generator_loss:2.5963
# L1_loss:0.1858
# Discriminator_loss:0.7886
#
# EPOCH[103] - STEP[200]
# Generator_loss:0.6485
# L1_loss:0.1598
# Discriminator_loss:1.5805
#
# EPOCH[104] - STEP[200]
# Generator_loss:1.2136
# L1_loss:0.1720
# Discriminator_loss:1.6710
#
# EPOCH[105] - STEP[200]
# Generator_loss:0.5734
# L1_loss:0.1960
# Discriminator_loss:1.0089
#
# EPOCH[106] - STEP[200]
# Generator_loss:1.4248
# L1_loss:0.1759
# Discriminator_loss:0.6611
#
# EPOCH[107] - STEP[200]
# Generator_loss:0.9928
# L1_loss:0.2291
# Discriminator_loss:0.8154
#
# EPOCH[108] - STEP[200]
# Generator_loss:1.6774
# L1_loss:0.1629
# Discriminator_loss:0.6123
#
# EPOCH[109] - STEP[200]
# Generator_loss:2.2552
# L1_loss:0.1724
# Discriminator_loss:2.3739
#
# EPOCH[110] - STEP[200]
# Generator_loss:1.9506
# L1_loss:0.1586
# Discriminator_loss:1.3842
#
# EPOCH[111] - STEP[200]
# Generator_loss:2.0731
# L1_loss:0.1703
# Discriminator_loss:1.2989
#
# EPOCH[112] - STEP[200]
# Generator_loss:0.7467
# L1_loss:0.1637
# Discriminator_loss:0.9708
#
# EPOCH[113] - STEP[200]
# Generator_loss:1.3465
# L1_loss:0.1794
# Discriminator_loss:0.7103
#
# EPOCH[114] - STEP[200]
# Generator_loss:0.9173
# L1_loss:0.1567
# Discriminator_loss:1.3891
#
# EPOCH[115] - STEP[200]
# Generator_loss:2.2652
# L1_loss:0.1784
# Discriminator_loss:0.8246
#
# EPOCH[116] - STEP[200]
# Generator_loss:1.8761
# L1_loss:0.1855
# Discriminator_loss:1.3905
#
# EPOCH[117] - STEP[200]
# Generator_loss:2.1060
# L1_loss:0.1915
# Discriminator_loss:0.6107
#
# EPOCH[118] - STEP[200]
# Generator_loss:1.3334
# L1_loss:0.2017
# Discriminator_loss:1.0471
#
# EPOCH[119] - STEP[200]
# Generator_loss:0.8085
# L1_loss:0.1573
# Discriminator_loss:1.0282
#
# EPOCH[120] - STEP[200]
# Generator_loss:2.6223
# L1_loss:0.1436
# Discriminator_loss:0.7907
#
# EPOCH[121] - STEP[200]
# Generator_loss:1.4134
# L1_loss:0.1792
# Discriminator_loss:0.7327
#
# EPOCH[122] - STEP[200]
# Generator_loss:1.5800
# L1_loss:0.1549
# Discriminator_loss:0.9608
#
# EPOCH[123] - STEP[200]
# Generator_loss:1.4051
# L1_loss:0.1480
# Discriminator_loss:0.8712
#
# EPOCH[124] - STEP[200]
# Generator_loss:2.1333
# L1_loss:0.1779
# Discriminator_loss:0.5807
#
# EPOCH[125] - STEP[200]
# Generator_loss:1.6491
# L1_loss:0.1288
# Discriminator_loss:1.7281
#
# EPOCH[126] - STEP[200]
# Generator_loss:0.3914
# L1_loss:0.1448
# Discriminator_loss:1.4314
#
# EPOCH[127] - STEP[200]
# Generator_loss:2.1969
# L1_loss:0.1531
# Discriminator_loss:1.8699
#
# EPOCH[128] - STEP[200]
# Generator_loss:1.5232
# L1_loss:0.1437
# Discriminator_loss:1.4543
#
# EPOCH[129] - STEP[200]
# Generator_loss:2.3049
# L1_loss:0.1931
# Discriminator_loss:0.2524
#
# EPOCH[130] - STEP[200]
# Generator_loss:1.5626
# L1_loss:0.1885
# Discriminator_loss:1.4854
#
# EPOCH[131] - STEP[200]
# Generator_loss:2.3509
# L1_loss:0.1828
# Discriminator_loss:1.9240
#
# EPOCH[132] - STEP[200]
# Generator_loss:2.6501
# L1_loss:0.1803
# Discriminator_loss:0.1846
#
# EPOCH[133] - STEP[200]
# Generator_loss:0.6901
# L1_loss:0.1957
# Discriminator_loss:0.9261
#
# EPOCH[134] - STEP[200]
# Generator_loss:0.6472
# L1_loss:0.1718
# Discriminator_loss:1.0598
#
# EPOCH[135] - STEP[200]
# Generator_loss:1.6617
# L1_loss:0.1520
# Discriminator_loss:0.6088
#
# EPOCH[136] - STEP[200]
# Generator_loss:0.8811
# L1_loss:0.1642
# Discriminator_loss:0.7395
#
# EPOCH[137] - STEP[200]
# Generator_loss:1.5494
# L1_loss:0.1580
# Discriminator_loss:0.8787
#
# EPOCH[138] - STEP[200]
# Generator_loss:2.1338
# L1_loss:0.1502
# Discriminator_loss:2.2212
#
# EPOCH[139] - STEP[200]
# Generator_loss:1.4742
# L1_loss:0.1870
# Discriminator_loss:0.4379
#
# EPOCH[140] - STEP[200]
# Generator_loss:1.7386
# L1_loss:0.1958
# Discriminator_loss:0.2404
#
# EPOCH[141] - STEP[200]
# Generator_loss:1.2655
# L1_loss:0.1790
# Discriminator_loss:0.4528
#
# EPOCH[142] - STEP[200]
# Generator_loss:0.5626
# L1_loss:0.1829
# Discriminator_loss:0.9921
#
# EPOCH[143] - STEP[200]
# Generator_loss:1.4503
# L1_loss:0.1642
# Discriminator_loss:0.3264
#
# EPOCH[144] - STEP[200]
# Generator_loss:2.2839
# L1_loss:0.1695
# Discriminator_loss:0.7684
#
# EPOCH[145] - STEP[200]
# Generator_loss:1.3379
# L1_loss:0.1666
# Discriminator_loss:1.0835
#
# EPOCH[146] - STEP[200]
# Generator_loss:1.4460
# L1_loss:0.1402
# Discriminator_loss:0.4974
#
# EPOCH[147] - STEP[200]
# Generator_loss:1.3474
# L1_loss:0.1813
# Discriminator_loss:0.9962
#
# EPOCH[148] - STEP[200]
# Generator_loss:2.3202
# L1_loss:0.1702
# Discriminator_loss:0.6185
#
# EPOCH[149] - STEP[200]
# Generator_loss:0.6617
# L1_loss:0.1559
# Discriminator_loss:2.2958
#
# EPOCH[150] - STEP[200]
# Generator_loss:1.2476
# L1_loss:0.1674
# Discriminator_loss:1.8176
#
# EPOCH[151] - STEP[200]
# Generator_loss:1.7838
# L1_loss:0.2210
# Discriminator_loss:0.2174
#
# EPOCH[152] - STEP[200]
# Generator_loss:1.2127
# L1_loss:0.1646
# Discriminator_loss:1.2861
#
# EPOCH[153] - STEP[200]
# Generator_loss:0.7612
# L1_loss:0.2253
# Discriminator_loss:0.7657
#
# EPOCH[154] - STEP[200]
# Generator_loss:1.8314
# L1_loss:0.1602
# Discriminator_loss:2.6413
#
# EPOCH[155] - STEP[200]
# Generator_loss:2.1635
# L1_loss:0.1685
# Discriminator_loss:0.6797
#
# EPOCH[156] - STEP[200]
# Generator_loss:0.6704
# L1_loss:0.1577
# Discriminator_loss:2.9402
#
# EPOCH[157] - STEP[200]
# Generator_loss:1.4582
# L1_loss:0.2125
# Discriminator_loss:0.3503
#
# EPOCH[158] - STEP[200]
# Generator_loss:1.0321
# L1_loss:0.1777
# Discriminator_loss:0.6032
#
# EPOCH[159] - STEP[200]
# Generator_loss:1.4411
# L1_loss:0.1468
# Discriminator_loss:1.1340
#
# EPOCH[160] - STEP[200]
# Generator_loss:0.5448
# L1_loss:0.1701
# Discriminator_loss:1.1376
#
# EPOCH[161] - STEP[200]
# Generator_loss:1.5080
# L1_loss:0.2014
# Discriminator_loss:0.3405
#
# EPOCH[162] - STEP[200]
# Generator_loss:2.5908
# L1_loss:0.2036
# Discriminator_loss:0.3521
#
# EPOCH[163] - STEP[200]
# Generator_loss:0.4407
# L1_loss:0.1516
# Discriminator_loss:1.4223
#
# EPOCH[164] - STEP[200]
# Generator_loss:0.3972
# L1_loss:0.1692
# Discriminator_loss:1.3155
#
# EPOCH[165] - STEP[200]
# Generator_loss:1.3863
# L1_loss:0.1569
# Discriminator_loss:1.3566
#
# EPOCH[166] - STEP[200]
# Generator_loss:1.6193
# L1_loss:0.1708
# Discriminator_loss:0.3766
#
# EPOCH[167] - STEP[200]
# Generator_loss:0.6804
# L1_loss:0.1355
# Discriminator_loss:1.3929
#
# EPOCH[168] - STEP[200]
# Generator_loss:1.9451
# L1_loss:0.1372
# Discriminator_loss:0.7157
#
# EPOCH[169] - STEP[200]
# Generator_loss:1.1083
# L1_loss:0.1698
# Discriminator_loss:0.8261
#
# EPOCH[170] - STEP[200]
# Generator_loss:2.2444
# L1_loss:0.1767
# Discriminator_loss:0.4749
#
# EPOCH[171] - STEP[200]
# Generator_loss:1.2200
# L1_loss:0.1582
# Discriminator_loss:0.9931
#
# EPOCH[172] - STEP[200]
# Generator_loss:1.6656
# L1_loss:0.1620
# Discriminator_loss:0.8457
#
# EPOCH[173] - STEP[200]
# Generator_loss:1.0458
# L1_loss:0.1652
# Discriminator_loss:0.7923
#
# EPOCH[174] - STEP[200]
# Generator_loss:1.6598
# L1_loss:0.1671
# Discriminator_loss:0.8194
#
# EPOCH[175] - STEP[200]
# Generator_loss:0.7224
# L1_loss:0.2277
# Discriminator_loss:1.4132
#
# EPOCH[176] - STEP[200]
# Generator_loss:1.0064
# L1_loss:0.1861
# Discriminator_loss:0.6192
#
# EPOCH[177] - STEP[200]
# Generator_loss:1.8411
# L1_loss:0.1608
# Discriminator_loss:2.0357
#
# EPOCH[178] - STEP[200]
# Generator_loss:0.6097
# L1_loss:0.1653
# Discriminator_loss:1.0951
#
# EPOCH[179] - STEP[200]
# Generator_loss:2.4894
# L1_loss:0.1558
# Discriminator_loss:2.5777
#
# EPOCH[180] - STEP[200]
# Generator_loss:0.9822
# L1_loss:0.1447
# Discriminator_loss:0.8991
#
# EPOCH[181] - STEP[200]
# Generator_loss:1.4946
# L1_loss:0.1999
# Discriminator_loss:0.3107
#
# EPOCH[182] - STEP[200]
# Generator_loss:1.7625
# L1_loss:0.1279
# Discriminator_loss:1.7088
#
# EPOCH[183] - STEP[200]
# Generator_loss:0.6022
# L1_loss:0.1629
# Discriminator_loss:1.1114
#
# EPOCH[184] - STEP[200]
# Generator_loss:2.2131
# L1_loss:0.1901
# Discriminator_loss:0.1701
#
# EPOCH[185] - STEP[200]
# Generator_loss:1.7583
# L1_loss:0.1929
# Discriminator_loss:0.5133
#
# EPOCH[186] - STEP[200]
# Generator_loss:0.4483
# L1_loss:0.1741
# Discriminator_loss:1.3479
#
# EPOCH[187] - STEP[200]
# Generator_loss:0.4730
# L1_loss:0.1488
# Discriminator_loss:1.9340
#
# EPOCH[188] - STEP[200]
# Generator_loss:1.5855
# L1_loss:0.1387
# Discriminator_loss:1.6615
#
# EPOCH[189] - STEP[200]
# Generator_loss:2.0811
# L1_loss:0.1345
# Discriminator_loss:1.2898
#
# EPOCH[190] - STEP[200]
# Generator_loss:0.9325
# L1_loss:0.1636
# Discriminator_loss:0.6761
#
# EPOCH[191] - STEP[200]
# Generator_loss:1.5920
# L1_loss:0.1707
# Discriminator_loss:0.6942
#
# EPOCH[192] - STEP[200]
# Generator_loss:1.1235
# L1_loss:0.1813
# Discriminator_loss:0.4950
#
# EPOCH[193] - STEP[200]
# Generator_loss:1.5477
# L1_loss:0.1786
# Discriminator_loss:0.4293
#
# EPOCH[194] - STEP[200]
# Generator_loss:1.0491
# L1_loss:0.1742
# Discriminator_loss:0.6141
#
# EPOCH[195] - STEP[200]
# Generator_loss:1.7886
# L1_loss:0.1695
# Discriminator_loss:0.4692
#
# EPOCH[196] - STEP[200]
# Generator_loss:0.6109
# L1_loss:0.1839
# Discriminator_loss:0.9479
#
# EPOCH[197] - STEP[200]
# Generator_loss:0.6026
# L1_loss:0.1461
# Discriminator_loss:1.7484
#
# EPOCH[198] - STEP[200]
# Generator_loss:1.9756
# L1_loss:0.1697
# Discriminator_loss:0.6904
#
# EPOCH[199] - STEP[200]
# Generator_loss:1.0253
# L1_loss:0.1780
# Discriminator_loss:1.1741
#
# EPOCH[200] - STEP[200]
# Generator_loss:1.5014
# L1_loss:0.1406
# Discriminator_loss:0.9939

# %% [markdown]
# ### 테스트 결과 시각화

# %%
test_ind = 1

test_path = os.getenv('HOME') + '/aiffel/exploration/E19/data/cityscapes/val/'

f = test_path + os.listdir(test_path)[test_ind]
input_image, orig_image = load_img(f)

pred = generator(tf.expand_dims(input_image, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(input_image)); plt.title('Input', fontsize=25)
plt.subplot(1,3,2); plt.imshow(pred[0]); plt.title('Output', fontsize=25)
plt.subplot(1,3,3); plt.imshow(denormalize(orig_image)); plt.title('Ground Truth', fontsize=25)
# Out:
# Text(0.5, 1.0, 'Ground Truth')

# %% [markdown]
# ### 중간 손실 값 로그 기록

# %%
plt.figure(figsize=(16,10))

plt.subplot(311)
plt.plot(history['gen_loss'])
plt.title('Generator Loss')

plt.subplot(312)
plt.plot(history['l1_loss'])
plt.title('L1 Loss')

plt.subplot(313)
plt.plot(history['disc_loss'])
plt.title('Discriminator Loss')

plt.show()

# %% [markdown]
# ## 5. 회고

# %% [markdown]
# - 개념 자체가 쉬운 노드는 아니었지만, GAN은 생성자와 판별자를 활용해 무에서 유를 창조한다는 점에서 항상 흥미로운 모델 구현방식인 것 같다.
#
#
# - Fundamental Node에서 Tensorflow 예제를 통해 Subclassing API를 학습 했었는데, 실제 GAN 모델을 활용해 Subclassing API 실습을 해볼 수 있었던 노드였다. 특히, Generator, Discriminator 모델 부분을 좀 더 자세히 공부해야할 것 같다.
#
#
# - 모델 학습을 10, 100, 200번 순으로 반복하여 진행하였다. 100번 학습을 시켰을 때 학습을 두배로 시키면 좋은 이미지가 나올 것 같아 시간을 투자해 200번 학습을 시켰더니 노이즈는 있지만 어느 정도 그럴싸한 도로 이미지가 생성되었다.
